# %%
import pandas as pd
import os
from nba_api.stats.endpoints import playerindex, playbyplayv3
import utils.data_utils as du
import importlib
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
HOME_DIR = '/Users/yoav/Documents/Yoav/CS/20936 - DS Project/Shotpred'
DATA_DIR = os.path.join(HOME_DIR, 'data')
EXT_DATA_DIR = os.path.join(DATA_DIR, 'External')
INT_DATA_DIR = os.path.join(DATA_DIR, 'Internal')

# %%
KAGGLE_SHOT_LOGS_201415_FILENAME = 'kaggle_shot_logs_2014_15.csv'
KAGGLE_SHOT_LOGS_201415_FULLPATH = os.path.join(EXT_DATA_DIR, KAGGLE_SHOT_LOGS_201415_FILENAME)

GENERAL_SHOT_LOGS_FILENAME = 'nba_2015_shots.csv'
GENERAL_SHOT_LOGS_FULLPATH = os.path.join(EXT_DATA_DIR, GENERAL_SHOT_LOGS_FILENAME)

# %%
KAGGLE_COLS_FOR_MERGE = ['GAME_ID', 'SHOT_CLOCK', 'DRIBBLES', 'TOUCH_TIME', 'CLOSEST_DEFENDER', 'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST', 'player_id', 'absolute_game_time']
CAREER_STATS_COL_FOR_MERGE = ['PLAYER_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT'] #already filtered for relevant season

# %%
shot_logs_1415 = pd.read_csv(KAGGLE_SHOT_LOGS_201415_FULLPATH)

# %%
active_players_201415_ids = shot_logs_1415['player_id'].unique()

# %%
shot_logs_1415['absolute_game_time'] = shot_logs_1415.apply(lambda row: du.clock_to_absolute_seconds(row['GAME_CLOCK'], row['PERIOD']), axis=1)

# %%
#active_players_career_stats = du.gather_mul_career_stats(active_players_201415_ids) # get the career stats for all active players in 2014-15 season

# %%
#active_players_cs_in_1415 = active_players_career_stats[active_players_career_stats['SEASON_ID'] == '2014-15'].reset_index(drop=True)
#active_players_cs_in_1415.to_csv(INT_DATA_DIR + 'active_players_career_stats_2014_15.csv', index=False)

# %%
active_players_cs_in_1415 = pd.read_csv(os.path.join(INT_DATA_DIR, 'active_players_career_stats_2014_15.csv'))

# %%
gen_sl = pd.read_csv(GENERAL_SHOT_LOGS_FULLPATH)

# %%
gen_sl.head()
# Out:
#    SEASON_1 SEASON_2     TEAM_ID              TEAM_NAME  PLAYER_ID  \
# 0      2015  2014-15  1610612743         Denver Nuggets     203115
# 1      2015  2014-15  1610612744  Golden State Warriors     203949
# 2      2015  2014-15  1610612739    Cleveland Cavaliers       1890
# 3      2015  2014-15  1610612744  Golden State Warriors     203949
# 4      2015  2014-15  1610612743         Denver Nuggets     203475
#
#             PLAYER_NAME POSITION_GROUP POSITION   GAME_DATE   GAME_ID  ...  \
# 0           Will Barton              G       SG  04-15-2015  21401229  ...
# 1  James Michael McAdoo              F       PF  04-15-2015  21401229  ...
# 2          Shawn Marion              F       SF  04-15-2015  21401225  ...
# 3  James Michael McAdoo              F       PF  04-15-2015  21401229  ...
# 4           Erick Green              G       PG  04-15-2015  21401229  ...
#
#         BASIC_ZONE  ZONE_NAME ZONE_ABB       ZONE_RANGE LOC_X  LOC_Y  \
# 0  Restricted Area     Center        C  Less Than 8 ft.  -0.4   6.75
# 1  Restricted Area     Center        C  Less Than 8 ft.  -0.0   5.35
# 2  Restricted Area     Center        C  Less Than 8 ft.  -0.0   5.35
# 3  Restricted Area     Center        C  Less Than 8 ft.  -0.0   5.35
# 4        Mid-Range  Left Side        L        16-24 ft.  16.9  14.85
#
#   SHOT_DISTANCE QUARTER MINS_LEFT SECS_LEFT
# 0             1       4         0        18
# 1             0       4         0        22
# 2             0       5         0         3
# 3             0       4         0        37
# 4            19       4         0        48
#
# [5 rows x 26 columns]

# %%
gen_sl['absolute_game_time'] = gen_sl.apply(lambda row: du.clock_to_absolute_seconds(f"{str(row["MINS_LEFT"]).zfill(2)}:{str(row["SECS_LEFT"]).zfill(2)}", row['QUARTER']), axis=1)

# %%
kaggle_for_join = shot_logs_1415[KAGGLE_COLS_FOR_MERGE]

# %%
kaggle_for_join.head()
# Out:
#     GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME  CLOSEST_DEFENDER  \
# 0  21400468        22.0         2         1.8      Joseph, Cory
# 1  21400818        21.8         3         3.2     Rose, Derrick
# 2  21400892        22.5         2         2.5  Carroll, DeMarre
# 3  21400292        21.1         0         1.3    Fournier, Evan
# 4  21400855        20.6         0         0.0      Ibaka, Serge
#
#    CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  absolute_game_time
# 0                      202709             2.3       2754                 3.0
# 1                      201565             5.3     202693                 4.0
# 2                      201960             3.5       2772                 4.0
# 3                      203095             3.4     203463                 4.0
# 4                      201586             4.0     202693                 4.0

# %%
gen_sl_game_ids = set(gen_sl['GAME_ID'].unique())
kaggle_for_join_game_ids = set(kaggle_for_join['GAME_ID'].unique())

common_game_ids = gen_sl_game_ids.intersection(kaggle_for_join_game_ids)

print(f"Number of unique GAME_IDs in gen_sl: {len(gen_sl_game_ids)}")
print(f"Number of unique GAME_IDs in kaggle_for_join: {len(kaggle_for_join_game_ids)}")
print(f"Number of common GAME_IDs in both: {len(common_game_ids)}")
# Out:
# Number of unique GAME_IDs in gen_sl: 1230
# Number of unique GAME_IDs in kaggle_for_join: 904
# Number of common GAME_IDs in both: 904

# %%
kg = kaggle_for_join.sort_values(by='ABS_TIME').reset_index(drop=True)

# %%
kaggle_for_join
# Out:
#          GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME   CLOSEST_DEFENDER  \
# 0       21400899        10.8         2         1.9     Anderson, Alan
# 1       21400899         3.4         0         0.8  Bogdanovic, Bojan
# 2       21400899         NaN         3         2.7  Bogdanovic, Bojan
# 3       21400899        10.3         2         1.9      Brown, Markel
# 4       21400899        10.9         2         2.7    Young, Thaddeus
# ...          ...         ...       ...         ...                ...
# 128064  21400006        18.3         5         6.2      Smart, Marcus
# 128065  21400006        19.8         4         5.2       Turner, Evan
# 128066  21400006        23.0         2         4.2   Thornton, Marcus
# 128067  21400006         9.1         4         4.5     Bradley, Avery
# 128068  21400006         NaN         5         4.7     Bradley, Avery
#
#         CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  \
# 0                           101187             1.3     203148
# 1                           202711             6.1     203148
# 2                           202711             0.9     203148
# 3                           203900             3.4     203148
# 4                           201152             1.1     203148
# ...                            ...             ...        ...
# 128064                      203935             0.8     101127
# 128065                      202323             0.6     101127
# 128066                      201977             4.2     101127
# 128067                      202340             3.0     101127
# 128068                      202340             2.3     101127
#
#         absolute_game_time
# 0                    651.0
# 1                    706.0
# 2                    720.0
# 3                    733.0
# 4                    806.0
# ...                    ...
# 128064              2048.0
# 128065              2192.0
# 128066              2210.0
# 128067              2723.0
# 128068              2868.0
#
# [128069 rows x 9 columns]

# %%
kaggle_for_join = kaggle_for_join.sort_values(by=['absolute_game_time']).reset_index(drop=True)

# %%
gen_sl = gen_sl.sort_values(by=['absolute_game_time']).reset_index(drop=True)
gen_sl['gen_sl_time_copy'] = gen_sl['absolute_game_time']

# %%
merged = pd.merge_asof(kaggle_for_join, gen_sl, on='absolute_game_time',left_by=['player_id', 'GAME_ID'], right_by=['PLAYER_ID', 'GAME_ID'],  direction='nearest', suffixes=['_kaggle', '_shot_logs'], tolerance=5) #,left_by=['player_id', 'GAME_ID'], right_by=['PLAYER_ID', 'GAME_ID'],

# %%
merged.head()
# Out:
#     GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME  CLOSEST_DEFENDER  \
# 0  21400468        22.0         2         1.8      Joseph, Cory
# 1  21400818        21.8         3         3.2     Rose, Derrick
# 2  21400892        22.5         2         2.5  Carroll, DeMarre
# 3  21400292        21.1         0         1.3    Fournier, Evan
# 4  21400855        20.6         0         0.0      Ibaka, Serge
#
#    CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  absolute_game_time  \
# 0                      202709             2.3       2754                 3.0
# 1                      201565             5.3     202693                 4.0
# 2                      201960             3.5       2772                 4.0
# 3                      203095             3.4     203463                 4.0
# 4                      201586             4.0     202693                 4.0
#
#    SEASON_1  ... ZONE_ABB       ZONE_RANGE LOC_X  LOC_Y SHOT_DISTANCE QUARTER  \
# 0    2015.0  ...        C  Less Than 8 ft.  -0.6   5.35           0.0     1.0
# 1    2015.0  ...        C  Less Than 8 ft.   1.5   6.45           1.0     1.0
# 2    2015.0  ...        C  Less Than 8 ft.  -2.4   5.05           2.0     1.0
# 3    2015.0  ...        C  Less Than 8 ft.  -2.2   6.65           2.0     1.0
# 4    2015.0  ...        C  Less Than 8 ft.  -0.0   5.35           0.0     1.0
#
#   MINS_LEFT SECS_LEFT ABS_TIME gen_sl_time_copy
# 0      11.0      54.0      6.0              6.0
# 1      11.0      51.0      9.0              9.0
# 2      11.0      52.0      8.0              8.0
# 3      11.0      54.0      6.0              6.0
# 4      11.0      55.0      5.0              5.0
#
# [5 rows x 36 columns]

# %%
not_merged = merged[merged.gen_sl_time_copy.isna()]

# %%
not_merged.head()
# Out:
#       GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME CLOSEST_DEFENDER  \
# 173  21400471        22.9         0         2.1     Hill, Jordan
# 183  21400345        11.6         2         5.0     Conley, Mike
# 236  21400872        11.2         0         0.0    Amundson, Lou
# 254  21400322        10.9         0         4.6     Joseph, Cory
# 369  21400515         9.6         5         4.1    Holiday, Jrue
#
#      CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  \
# 173                      201941             2.6     202389
# 183                      201144             0.3     203487
# 236                      200811             3.7     202685
# 254                      202709             2.9     101181
# 369                      201950             5.7     202322
#
#      absolute_game_time  SEASON_1  ... ZONE_ABB  ZONE_RANGE LOC_X  LOC_Y  \
# 173                13.0       NaN  ...      NaN         NaN   NaN    NaN
# 183                13.0       NaN  ...      NaN         NaN   NaN    NaN
# 236                14.0       NaN  ...      NaN         NaN   NaN    NaN
# 254                14.0       NaN  ...      NaN         NaN   NaN    NaN
# 369                16.0       NaN  ...      NaN         NaN   NaN    NaN
#
#     SHOT_DISTANCE QUARTER MINS_LEFT SECS_LEFT ABS_TIME gen_sl_time_copy
# 173           NaN     NaN       NaN       NaN      NaN              NaN
# 183           NaN     NaN       NaN       NaN      NaN              NaN
# 236           NaN     NaN       NaN       NaN      NaN              NaN
# 254           NaN     NaN       NaN       NaN      NaN              NaN
# 369           NaN     NaN       NaN       NaN      NaN              NaN
#
# [5 rows x 36 columns]

# %%
not_merged
# Out:
#          GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME CLOSEST_DEFENDER  \
# 173     21400471        22.9         0         2.1     Hill, Jordan
# 183     21400345        11.6         2         5.0     Conley, Mike
# 236     21400872        11.2         0         0.0    Amundson, Lou
# 254     21400322        10.9         0         4.6     Joseph, Cory
# 369     21400515         9.6         5         4.1    Holiday, Jrue
# ...          ...         ...       ...         ...              ...
# 127143  21400307        24.0         0         3.2   Griffin, Blake
# 127495  21400288         7.7         1         3.0      Sims, Henry
# 127581  21400496         9.6         1         1.5       Gasol, Pau
# 127867  21400302        17.3         0         0.0     Turner, Evan
# 127904  21400375         2.8         0         0.8   Randolph, Zach
#
#         CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  \
# 173                         201941             2.6     202389
# 183                         201144             0.3     203487
# 236                         200811             3.7     202685
# 254                         202709             2.9     101181
# 369                         201950             5.7     202322
# ...                            ...             ...        ...
# 127143                      201933             2.3     200782
# 127495                      203156             3.5     203484
# 127581                        2200             2.3     202323
# 127867                      202323             5.4     101162
# 127904                        2216             9.2       2564
#
#         absolute_game_time  SEASON_1  ... ZONE_ABB  ZONE_RANGE LOC_X  LOC_Y  \
# 173                   13.0       NaN  ...      NaN         NaN   NaN    NaN
# 183                   13.0       NaN  ...      NaN         NaN   NaN    NaN
# 236                   14.0       NaN  ...      NaN         NaN   NaN    NaN
# 254                   14.0       NaN  ...      NaN         NaN   NaN    NaN
# 369                   16.0       NaN  ...      NaN         NaN   NaN    NaN
# ...                    ...       ...  ...      ...         ...   ...    ...
# 127143              3379.0       NaN  ...      NaN         NaN   NaN    NaN
# 127495              3502.0       NaN  ...      NaN         NaN   NaN    NaN
# 127581              3532.0       NaN  ...      NaN         NaN   NaN    NaN
# 127867              4049.0       NaN  ...      NaN         NaN   NaN    NaN
# 127904              4125.0       NaN  ...      NaN         NaN   NaN    NaN
#
#        SHOT_DISTANCE QUARTER MINS_LEFT SECS_LEFT ABS_TIME gen_sl_time_copy
# 173              NaN     NaN       NaN       NaN      NaN              NaN
# 183              NaN     NaN       NaN       NaN      NaN              NaN
# 236              NaN     NaN       NaN       NaN      NaN              NaN
# 254              NaN     NaN       NaN       NaN      NaN              NaN
# 369              NaN     NaN       NaN       NaN      NaN              NaN
# ...              ...     ...       ...       ...      ...              ...
# 127143           NaN     NaN       NaN       NaN      NaN              NaN
# 127495           NaN     NaN       NaN       NaN      NaN              NaN
# 127581           NaN     NaN       NaN       NaN      NaN              NaN
# 127867           NaN     NaN       NaN       NaN      NaN              NaN
# 127904           NaN     NaN       NaN       NaN      NaN              NaN
#
# [766 rows x 36 columns]

# %%
not_merged_in_gsg = pd.merge(not_merged, gsg, on=['GAME_ID', 'ABS_TIME', 'PLAYER_ID'], how='left', indicator=True)
#not_merged_in_gsg = not_merged_in_gsg[not_merged_in_gsg['_merge'] == 'both']
not_merged_in_gsg#
# Out:
#       GAME_ID  ABS_TIME  PLAYER_ID  NUMBO  gsg_abs_dup_x  gsg_abs_dup_y  \
# 0    21400345      13.0     203487    NaN            NaN            NaN
# 1    21400471      13.0     202389    NaN            NaN            NaN
# 2    21400872      14.0     202685    NaN            NaN            NaN
# 3    21400322      14.0     101181    NaN            NaN            NaN
# 4    21400515      16.0     202322    NaN            NaN            NaN
# ..        ...       ...        ...    ...            ...            ...
# 761  21400307    3379.0     200782    NaN            NaN            NaN
# 762  21400288    3502.0     203484    NaN            NaN            NaN
# 763  21400496    3532.0     202323    NaN            NaN            NaN
# 764  21400302    4049.0     101162    NaN            NaN            NaN
# 765  21400375    4125.0       2564    NaN            NaN            NaN
#
#         _merge
# 0    left_only
# 1    left_only
# 2    left_only
# 3    left_only
# 4    left_only
# ..         ...
# 761  left_only
# 762  left_only
# 763  left_only
# 764  left_only
# 765  left_only
#
# [766 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(gsg['ABS_TIME'], label='gsg', marker='o')
plt.plot(kg['ABS_TIME'], label='kg', marker='x')

plt.xlabel('Shot Index')
plt.ylabel('Absolute Time')
plt.title('Shot Times in gsg vs Shot Times in kg')
plt.legend()
plt.grid(True)

plt.show()

# %%
heights = pd.read_csv(os.path.join(INT_DATA_DIR, 'nba_2014_2015_player_heights.csv'))

# %%
heights
# Out:
#        PLAYER_NAME HEIGHT
# 0         AJ Price    6-2
# 1     Aaron Brooks    6-0
# 2     Aaron Gordon    6-8
# 3    Adreian Payne   6-10
# 4       Al Horford    6-9
# ..             ...    ...
# 487   Xavier Henry    6-6
# 488    Zach LaVine    6-5
# 489  Zach Randolph    6-9
# 490  Zaza Pachulia   6-11
# 491   Zoran Dragic    6-5
#
# [492 rows x 2 columns]

# %%
merged.columns
# Out:
# Index(['GAME_ID', 'SHOT_CLOCK', 'DRIBBLES', 'TOUCH_TIME', 'CLOSEST_DEFENDER',
#        'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST', 'player_id',
#        'absolute_game_time', 'SEASON_1', 'SEASON_2', 'TEAM_ID', 'TEAM_NAME',
#        'PLAYER_ID', 'PLAYER_NAME', 'POSITION_GROUP', 'POSITION', 'GAME_DATE',
#        'HOME_TEAM', 'AWAY_TEAM', 'EVENT_TYPE', 'SHOT_MADE', 'ACTION_TYPE',
#        'SHOT_TYPE', 'BASIC_ZONE', 'ZONE_NAME', 'ZONE_ABB', 'ZONE_RANGE',
#        'LOC_X', 'LOC_Y', 'SHOT_DISTANCE', 'QUARTER', 'MINS_LEFT', 'SECS_LEFT',
#        'ABS_TIME', 'gen_sl_time_copy'],
#       dtype='object')

# %%
# Merge for attacker heights
merged_with_attacker_heights = pd.merge(merged, heights, left_on='PLAYER_NAME', right_on='PLAYER_NAME', suffixes=('', '_attacker'))

# Merge for defender heights
merged_with_both_heights = pd.merge(merged_with_attacker_heights, heights, left_on='CLOSEST_DEFENDER', right_on='PLAYER_NAME', suffixes=('_attacker', '_defender'))

# Drop the extra PLAYER_NAME column from the second merge
merged_with_both_heights = merged_with_both_heights.drop(columns=['PLAYER_NAME_defender'])

merged_with_both_heights.head()
# Out:
#     GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME CLOSEST_DEFENDER  \
# 0  21400579         NaN         0         5.2             Nene
# 1  21400776         9.8         0         1.1             Nene
# 2  21400179         2.9         1         1.7             Nene
# 3  21400427         0.5         2         5.2             Nene
# 4  21400656         8.5         2         2.8             Nene
#
#    CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  absolute_game_time  \
# 0                        2403             3.1       2200                17.0
# 1                        2403             5.7     101112                17.0
# 2                        2403             5.8       2544                22.0
# 3                        2403             0.1       2405                25.0
# 4                        2403             3.1     200746                31.0
#
#    SEASON_1  ... LOC_X  LOC_Y SHOT_DISTANCE  QUARTER MINS_LEFT SECS_LEFT  \
# 0    2015.0  ...  14.6   4.75          14.0      1.0      11.0      40.0
# 1    2015.0  ...   9.5  29.65          26.0      1.0      11.0      41.0
# 2    2015.0  ...   1.3  30.65          25.0      1.0      11.0      36.0
# 3    2015.0  ...   0.7   5.35           0.0      1.0      11.0      37.0
# 4    2015.0  ... -10.6  16.85          15.0      1.0      11.0      26.0
#
#   ABS_TIME gen_sl_time_copy HEIGHT_attacker HEIGHT_defender
# 0     20.0             20.0             7-0            6-11
# 1     19.0             19.0             7-0            6-11
# 2     24.0             24.0             6-9            6-11
# 3     23.0             23.0            6-10            6-11
# 4     34.0             34.0            6-11            6-11
#
# [5 rows x 38 columns]

# %%
heights.head()
# Out:
#      PLAYER_NAME HEIGHT
# 0       AJ Price    6-2
# 1   Aaron Brooks    6-0
# 2   Aaron Gordon    6-8
# 3  Adreian Payne   6-10
# 4     Al Horford    6-9

# %%
merged_with_attacker_heights.head()
# Out:
#     GAME_ID  SHOT_CLOCK  DRIBBLES  TOUCH_TIME  CLOSEST_DEFENDER  \
# 0  21400468        22.0         2         1.8      Joseph, Cory
# 1  21400818        21.8         3         3.2     Rose, Derrick
# 2  21400892        22.5         2         2.5  Carroll, DeMarre
# 3  21400292        21.1         0         1.3    Fournier, Evan
# 4  21400855        20.6         0         0.0      Ibaka, Serge
#
#    CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  player_id  absolute_game_time  \
# 0                      202709             2.3       2754                 3.0
# 1                      201565             5.3     202693                 4.0
# 2                      201960             3.5       2772                 4.0
# 3                      203095             3.4     203463                 4.0
# 4                      201586             4.0     202693                 4.0
#
#    SEASON_1  ...       ZONE_RANGE  LOC_X LOC_Y  SHOT_DISTANCE QUARTER  \
# 0    2015.0  ...  Less Than 8 ft.   -0.6  5.35            0.0     1.0
# 1    2015.0  ...  Less Than 8 ft.    1.5  6.45            1.0     1.0
# 2    2015.0  ...  Less Than 8 ft.   -2.4  5.05            2.0     1.0
# 3    2015.0  ...  Less Than 8 ft.   -2.2  6.65            2.0     1.0
# 4    2015.0  ...  Less Than 8 ft.   -0.0  5.35            0.0     1.0
#
#   MINS_LEFT SECS_LEFT ABS_TIME gen_sl_time_copy HEIGHT
# 0      11.0      54.0      6.0              6.0    6-4
# 1      11.0      51.0      9.0              9.0    6-9
# 2      11.0      52.0      8.0              8.0    6-8
# 3      11.0      54.0      6.0              6.0    6-3
# 4      11.0      55.0      5.0              5.0    6-9
#
# [5 rows x 37 columns]

# %%
COLS_FOR_PRED = ['SHOT_CLOCK', 'DRIBBLES', 'TOUCH_TIME', 'CLOSEST_DEFENDER_PLAYER_ID', 'CLOSE_DEF_DIST', 'absolute_game_time', 'SEASON_1', 'SEASON_2', 'TEAM_ID', 'PLAYER_ID', 'POSITION_GROUP', 'POSITION', 'GAME_DATE', 'HOME_TEAM', 'AWAY_TEAM', 'EVENT_TYPE', 'SHOT_MADE', 'ACTION_TYPE', 'SHOT_TYPE', 'BASIC_ZONE', 'ZONE_NAME', 'ZONE_ABB', 'ZONE_RANGE', 'LOC_X', 'LOC_Y', 'SHOT_DISTANCE', 'QUARTER', 'MINS_LEFT', 'SECS_LEFT', 'HEIGHT_attacker', 'HEIGHT_defender'] 

# interchange SEASON1/SEASON2
# maybe the game date is highly correlated with season so leave only game date
# probably need to chose only subset of the game time/qtr/mins_left/secs_left features
# SHOT_MADE and EVENT_TYPE is g.t

# %%
for_pred = merged_with_both_heights[COLS_FOR_PRED]

# %%
def visualize_distributions(df):
    """
    Create visualizations for data distributions
    """
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    numerical_cols = numerical_cols.drop(['PLAYER_ID', 'CLOSEST_DEFENDER_PLAYER_ID', 'SEASON_1'])
    
    # Distribution plots for numerical columns
    plt.figure(figsize=(15, 5 * (len(numerical_cols) // 3 + 1)))
    for i, col in enumerate(numerical_cols, 1):
        plt.subplot(len(numerical_cols) // 3 + 1, 3, i)
        sns.histplot(df[col], kde=True)
        plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()
    
    # Correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap')
    plt.show()

# %%
visualize_distributions(for_pred)

# %%
missing_summary = du.missing_values_summary(for_pred)
print(missing_summary)
# Out:
#             Missing Values  Percentage
# SHOT_CLOCK              24    6.349206

# %%
# check for duplicate rows in the data for prediction
duplicate_rows = for_pred[for_pred.duplicated()]

# display the duplicate rows
print(duplicate_rows)
# Out:
#      SHOT_CLOCK  DRIBBLES  TOUCH_TIME  CLOSEST_DEFENDER_PLAYER_ID  \
# 337         5.1         0         0.8                        2403
#
#      CLOSE_DEF_DIST  absolute_game_time  SEASON_1 SEASON_2       TEAM_ID  \
# 337             3.8              2638.0    2015.0  2014-15  1.610613e+09
#
#      PLAYER_ID  ... ZONE_ABB ZONE_RANGE LOC_X LOC_Y SHOT_DISTANCE QUARTER  \
# 337     2200.0  ...        L   8-16 ft.  15.5  5.25          15.0     4.0
#
#     MINS_LEFT SECS_LEFT HEIGHT_attacker HEIGHT_defender
# 337       3.0      59.0             7-0            6-11
#
# [1 rows x 31 columns]

# %%
importlib.reload(du)
constant_columns = du.find_constant_columns(for_pred)
print("Columns with constant values:", constant_columns)
# Out:
# Columns with constant values: ['CLOSEST_DEFENDER_PLAYER_ID', 'SEASON_1', 'SEASON_2', 'HEIGHT_defender']

# %%
for_pred
# Out:
#      SHOT_CLOCK  DRIBBLES  TOUCH_TIME  CLOSEST_DEFENDER_PLAYER_ID  \
# 0           NaN         0         5.2                        2403
# 1           9.8         0         1.1                        2403
# 2           2.9         1         1.7                        2403
# 3           0.5         2         5.2                        2403
# 4           8.5         2         2.8                        2403
# ..          ...       ...         ...                         ...
# 373         9.7        16        13.4                        2403
# 374         6.1         6         4.8                        2403
# 375         7.2        19        17.4                        2403
# 376        11.4        13        11.0                        2403
# 377         NaN         0         0.7                        2403
#
#      CLOSE_DEF_DIST  absolute_game_time  SEASON_1 SEASON_2       TEAM_ID  \
# 0               3.1                17.0    2015.0  2014-15  1.610613e+09
# 1               5.7                17.0    2015.0  2014-15  1.610613e+09
# 2               5.8                22.0    2015.0  2014-15  1.610613e+09
# 3               0.1                25.0    2015.0  2014-15  1.610613e+09
# 4               3.1                31.0    2015.0  2014-15  1.610613e+09
# ..              ...                 ...       ...      ...           ...
# 373             2.0              3406.0    2015.0  2014-15  1.610613e+09
# 374             2.1              3417.0    2015.0  2014-15  1.610613e+09
# 375             5.2              3452.0    2015.0  2014-15  1.610613e+09
# 376             5.1              3510.0    2015.0  2014-15  1.610613e+09
# 377             7.6              3597.0    2015.0  2014-15  1.610613e+09
#
#      PLAYER_ID  ... ZONE_ABB       ZONE_RANGE LOC_X  LOC_Y SHOT_DISTANCE  \
# 0       2200.0  ...        L         8-16 ft.  14.6   4.75          14.0
# 1     101112.0  ...       LC          24+ ft.   9.5  29.65          26.0
# 2       2544.0  ...        C          24+ ft.   1.3  30.65          25.0
# 3       2405.0  ...        C  Less Than 8 ft.   0.7   5.35           0.0
# 4     200746.0  ...        R         8-16 ft. -10.6  16.85          15.0
# ..         ...  ...      ...              ...   ...    ...           ...
# 373   200768.0  ...        C  Less Than 8 ft.  -1.3   5.85           1.0
# 374   201163.0  ...        C  Less Than 8 ft.  -2.4   8.55           4.0
# 375   200768.0  ...       LC        16-24 ft.   6.7  24.15          20.0
# 376   201951.0  ...       RC        16-24 ft. -14.4  16.75          18.0
# 377   201579.0  ...       LC          24+ ft.  12.3  29.15          26.0
#
#     QUARTER MINS_LEFT SECS_LEFT HEIGHT_attacker HEIGHT_defender
# 0       1.0      11.0      40.0             7-0            6-11
# 1       1.0      11.0      41.0             7-0            6-11
# 2       1.0      11.0      36.0             6-9            6-11
# 3       1.0      11.0      37.0            6-10            6-11
# 4       1.0      11.0      26.0            6-11            6-11
# ..      ...       ...       ...             ...             ...
# 373     5.0       3.0      11.0             6-0            6-11
# 374     5.0       3.0       0.0             6-8            6-11
# 375     5.0       2.0      25.0             6-0            6-11
# 376     5.0       1.0      28.0            5-11            6-11
# 377     5.0       0.0       1.0             7-2            6-11
#
# [378 rows x 31 columns]

# %%
for_prad = pd.merge(for_pred, active_players_cs_in_1415)

# %%
active_players_cs_in_1415
# Out:
#      PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0       203148   2014-15          0  1610612766               CHA        29.0
# 1       202687   2014-15          0  1610612766               CHA        22.0
# 2         2744   2014-15          0  1610612766               CHA        30.0
# 3       203469   2014-15          0  1610612766               CHA        22.0
# 4       202390   2014-15          0  1610612766               CHA        30.0
# ..         ...       ...        ...         ...               ...         ...
# 330     101114   2014-15          0  1610612751               BKN        31.0
# 331       2207   2014-15          0  1610612751               BKN        34.0
# 332     202366   2014-15          0  1610612751               BKN        28.0
# 333     202711   2014-15          0  1610612751               BKN        26.0
# 334     101127   2014-15          0  1610612751               BKN        31.0
#
#      GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0    72  10  1330.0  176  ...   0.892    13    96  109  162   33    6   57
# 1    64  21  1243.0  101  ...   0.583   159   248  407   16   18   99   52
# 2    65  61  1992.0  486  ...   0.655    99   449  548  113   47   84   68
# 3    62  45  1487.0  172  ...   0.774    97   265  362  100   34   49   62
# 4    43   0   931.0  143  ...   0.863    14    80   94   80   16    1   55
# ..   ..  ..     ...  ...  ...     ...   ...   ...  ...  ...  ...  ...  ...
# 330  68  55  2114.0  298  ...   0.834    29   208  237  448   64   17  154
# 331  80  80  2791.0  446  ...   0.801    53   331  384  292   59   14  137
# 332  44   0   383.0   50  ...   0.864    52    53  105   13    8   15   22
# 333  78  28  1854.0  261  ...   0.821    50   163  213   68   34    9   78
# 334  80  27  2241.0  359  ...   0.881    19   226  245  373   75   13  191
#
#       PF   PTS
# 0     75   480
# 1    140   304
# 2    139  1082
# 3    156   472
# 4     70   413
# ..   ...   ...
# 330  157   884
# 331  120  1154
# 332   58   138
# 333  104   700
# 334  143   957
#
# [335 rows x 27 columns]

# %%
CAREER_STATS_COL_FOR_MERGE
# Out:
# [['PLAYER_ID',
#   'FGM',
#   'FGA',
#   'FG_PCT',
#   'FG3M',
#   'FG3A',
#   'FG3_PCT',
#   'FTM',
#   'FTA',
#   'FT_PCT']]

# %%
cs_for_merge = active_players_cs_in_1415[CAREER_STATS_COL_FOR_MERGE]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 cs_for_merge = active_players_cs_in_1415[CAREER_STATS_COL_FOR_MERGE]
#
# File ~/Documents/Yoav/CS/20936 - DS Project/Shotpred/shots/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/Yoav/CS/20936 - DS Project/Shotpred/shots/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/Yoav/CS/20936 - DS Project/Shotpred/shots/lib/python3.13/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([('PLAYER_ID', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT')], dtype='object')] are in the [columns]"

# %%
def preprocess_data(df, target_column=None):
    """
    Perform data preprocessing steps
    """
    # Separate features and target
    if target_column:
        X = df.drop(target_column, axis=1)
        y = df[target_column]
    else:
        X = df
        y = None
    
    # Handle missing values
    numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
    categorical_cols = X.select_dtypes(include=['object']).columns
    
    # Numerical imputer
    num_imputer = SimpleImputer(strategy='mean')
    X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
    
    # Categorical imputer
    cat_imputer = SimpleImputer(strategy='most_frequent')
    X[categorical_cols] = cat_imputer.fit_transform(X[categorical_cols])
    
    # Encode categorical variables
    encoders = {}
    for col in categorical_cols:
        encoders[col] = LabelEncoder()
        X[col] = encoders[col].fit_transform(X[col])
    
    # Scale numerical features
    scaler = StandardScaler()
    X[numerical_cols] = scaler.fit_transform(X[numerical_cols])
    
    return X, y, encoders, scaler

# %%
bnk_pbp = playbyplayv3.PlayByPlayV3(game_id='0021400890').get_data_frames()[0]
bnk_pbp['ABS_TIME'] = bnk_pbp.apply(lambda row: du.clock_to_absolute_seconds(row['clock'], row['period']), axis=1)

# %%
bnk_pbp_shots = bnk_pbp[bnk_pbp.actionType.str.contains('shot', case=False)].reset_index(drop=True)

# %%
bnk_pbp_shots
# Out:
#          gameId  actionNumber        clock  period      teamId teamTricode  \
# 0    0021400890             2  PT11M44.00S       1  1610612747         LAL
# 1    0021400890             3  PT11M29.00S       1  1610612766         CHA
# 2    0021400890             5  PT11M14.00S       1  1610612747         LAL
# 3    0021400890             6  PT10M56.00S       1  1610612766         CHA
# 4    0021400890             8  PT10M43.00S       1  1610612747         LAL
# ..          ...           ...          ...     ...         ...         ...
# 160  0021400890           476  PT00M31.90S       4  1610612766         CHA
# 161  0021400890           478  PT00M22.80S       4  1610612747         LAL
# 162  0021400890           510  PT00M09.00S       4  1610612747         LAL
# 163  0021400890           525  PT00M04.80S       4  1610612747         LAL
# 164  0021400890           531  PT00M00.00S       4  1610612747         LAL
#
#      personId playerName   playerNameI  xLegacy  ...  scoreAway  pointsTotal  \
# 0      201961  Ellington  W. Ellington      234  ...          3            3
# 1      201945  Henderson  G. Henderson      125  ...                       0
# 2      203135      Sacre      R. Sacre       34  ...          5            5
# 3        2590   Williams   M. Williams     -163  ...                       0
# 4      203903   Clarkson   J. Clarkson      193  ...                       0
# ..        ...        ...           ...      ...  ...        ...          ...
# 160    201945  Henderson  G. Henderson     -142  ...                       0
# 161    201941       Hill       J. Hill       56  ...                       0
# 162    203903   Clarkson   J. Clarkson       -2  ...         98          199
# 163    201941       Hill       J. Hill        7  ...        100          203
# 164    202391        Lin        J. Lin     -112  ...        103          207
#
#     location                                        description   actionType  \
# 0          v  Ellington 24' 3PT Jump Shot (3 PTS) (Kelly 1 AST)    Made Shot
# 1          h                       MISS Henderson 18' Jump Shot  Missed Shot
# 2          v          Sacre 17' Jump Shot (2 PTS) (Kelly 2 AST)    Made Shot
# 3          h                    MISS Mo. Williams 20' Jump Shot  Missed Shot
# 4          v                    MISS Clarkson 26' 3PT Jump Shot  Missed Shot
# ..       ...                                                ...          ...
# 160        h                       MISS Henderson 17' Jump Shot  Missed Shot
# 161        v                            MISS Hill 19' Jump Shot  Missed Shot
# 162        v    Clarkson 1' Driving Layup (19 PTS) (Hill 2 AST)    Made Shot
# 163        v             Hill 1' Layup (10 PTS) (Johnson 3 AST)    Made Shot
# 164        v                     Lin 26' 3PT Jump Shot (23 PTS)    Made Shot
#
#                 subType  videoAvailable shotValue actionId ABS_TIME
# 0             Jump Shot               1         0        3     16.0
# 1             Jump Shot               1         0        4     31.0
# 2             Jump Shot               1         0        6     46.0
# 3             Jump Shot               1         0        7     64.0
# 4             Jump Shot               1         0        9     77.0
# ..                  ...             ...       ...      ...      ...
# 160           Jump Shot               1         0      428   2848.1
# 161           Jump Shot               1         0      430   2857.2
# 162  Driving Layup Shot               1         0      451   2871.0
# 163          Layup Shot               1         0      460   2875.2
# 164           Jump Shot               1         0      465   2880.0
#
# [165 rows x 25 columns]

# %%
gen_sl_abs_times = set(game_gen_sl['ABS_TIME'].unique())
pbp_times = set(bnk_pbp_shots['ABS_TIME'].unique())

common_game_ids = gen_sl_abs_times.intersection(pbp_times)

print(f"Number of unique in gen_sl: {len(gen_sl_abs_times)}")
print(f"Number of unique in pbp: {len(pbp_times)}")
print(f"Number of common in both: {len(common_game_ids)}")
# Out:
# Number of unique in gen_sl: 100
# Number of unique in pbp: 165
# Number of common in both: 93

# %%
ap_1415_index = playerindex.PlayerIndex(season='2014-15').get_data_frames()[0]

# %%
ap_1415_index.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_LAST_NAME', 'PLAYER_FIRST_NAME', 'PLAYER_SLUG',
#        'TEAM_ID', 'TEAM_SLUG', 'IS_DEFUNCT', 'TEAM_CITY', 'TEAM_NAME',
#        'TEAM_ABBREVIATION', 'JERSEY_NUMBER', 'POSITION', 'HEIGHT', 'WEIGHT',
#        'COLLEGE', 'COUNTRY', 'DRAFT_YEAR', 'DRAFT_ROUND', 'DRAFT_NUMBER',
#        'ROSTER_STATUS', 'FROM_YEAR', 'TO_YEAR', 'PTS', 'REB', 'AST',
#        'STATS_TIMEFRAME'],
#       dtype='object')

# %%
ap_1415_index_for_join = ap_1415_index[['PERSON_ID', 'HEIGHT']]
